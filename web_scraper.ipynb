# %%
# !pip install -q selenium beautifulsoup4 webdriver-manager

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time
from selenium.webdriver.support import expected_conditions as EC
from bs4 import BeautifulSoup
import pandas as pd
import json
import os
from collections import deque
import urllib.parse # to manipulate urls

# %%
# Chrome options
chrome_options = Options()
chrome_options.add_argument("--disable-http2")
chrome_options.add_argument("--incognito")
chrome_options.add_argument("--ignore-certificate-errors")
chrome_options.add_argument("--enable-features=NetworkServiceInProcess")
chrome_options.add_argument(
    "user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.63 Safari/537.36")
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')
# chrome_options.add_argument('--headless')

# %%
def wait_for_page_to_load(driver, wait):
    title = driver.title
    try:
        wait.until(
            lambda d: d.execute_script("return document.readyState") == "complete"
        )
        print(f"The Webpage {title} got fully loaded.")
    except:
        print(f"The Webpage {title} did not get loaded.")

# %%
def scraper(base_url="https://www.occamsadvisory.com/"):
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
    wait = WebDriverWait(driver, 10)
    driver.maximize_window()
    
    data  = [] # to store: {'url':str, 'content':str}
    visited = set() # to track already visited urls
    queue = deque([base_url]) # starting with homepage
    
    print("Starting scraping .....")
    while queue:
        current_url = queue.popleft() # getting next url (bfs)
        if current_url in visited:
            continue
        try:
            print(f"DEBUG: scraping url -> {current_url}")
            driver.get(current_url)
            wait_for_page_to_load(driver, wait)
            time.sleep(2) # extra delay for js rendering
            
            soup = BeautifulSoup(driver.page_source, 'html.parser')
            content = soup.get_text(separator="\n", strip=True)
            
            # adding url to data
            data.append({"url": current_url, "content": content})
            visited.add(current_url)
            
            # PREVIEW
            print(f"content length: {len(content)} chars\n")
            print(f"content snippet: {content[:200]}\n")
            print("-"*50 + "\n")
            
            # Find internal links 
            links = soup.find_all('a', href=True)
            for a in links:
                href = a['href']
                if not href or href.startswith("#") or href.startswith("mailto:") or href.startswith("tel:"):
                    continue # skipping achors, emails, phone numbers
                full_url = urllib.parse.urljoin(base_url, href)
                if "/blog/" in full_url:
                    print(f"DEBUG: skipping blog page -> {full_url}")
                    continue
                if "/podcasts" in full_url:
                    print(f"DEBUG: skipping podcast -> {full_url}")
                    continue
                if full_url.startswith(base_url) and full_url not in visited and full_url not in queue:
                    queue.append(full_url)
                    print(f"DEBUG: adding to the queue -> {full_url}")
                    
        except Exception as e:
            print(f"Can't scrape -> {current_url}: {e}\n")
            
    driver.quit()
    print(f"Scarping completed......")
    print(f"No of pages scraped: {len(data)}")
    return data

# %%
# exectuing scraping function
scraped_data = scraper()
# Out:
# Starting scraping .....
# DEBUG: scraping url -> https://www.occamsadvisory.com/
# The Webpage Occams Advisory | Global Financing Advisory & Professional Services got fully loaded.
# content length: 37859 chars
#
# content snippet: Occams Advisory | Global Financing Advisory & Professional Services
# Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payment
#
#
# --------------------------------------------------
#
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/career
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/awards
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/about
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/our-services
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/business-services-growth-incubation
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/financial-technology-payment-solutions
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/capital-markets-investment-banking
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/tax-credits
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/employer-of-record
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/structuring-incorporation-accounting-advisory
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/process-efficiency-compliance-tax-planning-filing
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/information-technology-services
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/merchant-accounts-across-the-globe
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/tailored-payment-solutions-verification-services
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/customized-payment-risk-management-analytics
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/proprietary-fintech-platform
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/capital-raising-to-promote-growth
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/financial-advisory-and-transaction-integration
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/sell-side-ma
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/buy-side-ma
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/decision-science-risk-assurance
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/employee-retention-tax-credits
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/research-and-development
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/our-team
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions/
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/events
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/insights
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/testimonials
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/contact
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/login
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/about#our_philo
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/audit-advisory
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/news/
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/faq
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/news/
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/about#impact
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/about#our-philosophies
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/from-what-if-to-even-if-the-mindset-behind-our-momentum/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/from-what-if-to-even-if-the-mindset-behind-our-momentum/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/schedule-a-free-consultation
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/press-release/
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/tax-credit
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/sitemap
# DEBUG: scraping url -> https://www.occamsadvisory.com/career
# The Webpage Career | Occams Advisory got fully loaded.
# content length: 15295 chars
#
# content snippet: Career | Occams Advisory
# Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payment
#
#
# --------------------------------------------------
#
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/career/find-a-job
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/about#mission&value
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: scraping url -> https://www.occamsadvisory.com/awards
# The Webpage Occams Advisory: Award-Winning Innovations and Recognitions got fully loaded.
# content length: 14850 chars
#
# content snippet: Occams Advisory: Award-Winning Innovations and Recognitions
# Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payment
#
#
# --------------------------------------------------
#
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: scraping url -> https://www.occamsadvisory.com/about
# The Webpage Your Trusted Partner for Financial Advisory - Occams Advisory got fully loaded.
# content length: 32424 chars
#
# content snippet: Your Trusted Partner for Financial Advisory - Occams Advisory
# Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payment
#
#
# --------------------------------------------------
#
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: scraping url -> https://www.occamsadvisory.com/our-services
# The Webpage Financial Advisory, Restructuring, Tax Credits & More | Occams Advisory got fully loaded.
# content length: 23826 chars
#
# content snippet: Financial Advisory, Restructuring, Tax Credits & More | Occams Advisory
# Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payment
#
#
# --------------------------------------------------
#
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/business-services-growth-incubation#bgsi-overview
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/business-services-growth-incubation#explore-bsgi
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/financial-technology-payment-solutions#ftps-overview
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/financial-technology-payment-solutions#ftps-explore
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/capital-markets-investment-banking#cmib-overview
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/capital-markets-investment-banking#cmib-explore
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/tax-credits#overview
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/tax-credits#explore
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/from-what-if-to-even-if-the-mindset-behind-our-momentum/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/from-what-if-to-even-if-the-mindset-behind-our-momentum/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: scraping url -> https://www.occamsadvisory.com/business-services-growth-incubation
# The Webpage Business Growth Incubation | Propel Your Venture with Occam's Advisory got fully loaded.
# content length: 50324 chars
#
# content snippet: Business Growth Incubation | Propel Your Venture with Occam's Advisory
# Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payment
#
#
# --------------------------------------------------
#
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/from-what-if-to-even-if-the-mindset-behind-our-momentum/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/from-what-if-to-even-if-the-mindset-behind-our-momentum/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: scraping url -> https://www.occamsadvisory.com/financial-technology-payment-solutions
# The Webpage Financial Technology & Payment Solutions | Occam's Advisory got fully loaded.
# content length: 49498 chars
#
# content snippet: Financial Technology & Payment Solutions | Occam's Advisory
# Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payment
#
#
# --------------------------------------------------
#
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/from-what-if-to-even-if-the-mindset-behind-our-momentum/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/from-what-if-to-even-if-the-mindset-behind-our-momentum/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: scraping url -> https://www.occamsadvisory.com/capital-markets-investment-banking
# The Webpage Capital Markets & Investment Banking Solutions | Occam's Advisory got fully loaded.
# content length: 49635 chars
#
# content snippet: Capital Markets & Investment Banking Solutions | Occam's Advisory
# Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payment
#
#
# --------------------------------------------------
#
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/from-what-if-to-even-if-the-mindset-behind-our-momentum/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/from-what-if-to-even-if-the-mindset-behind-our-momentum/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: scraping url -> https://www.occamsadvisory.com/tax-credits
# The Webpage Maximize Your Business Profits with Our Tax Credit Services got fully loaded.
# content length: 49147 chars
#
# content snippet: Maximize Your Business Profits with Our Tax Credit Services
# Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payment
#
#
# --------------------------------------------------
#
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/from-what-if-to-even-if-the-mindset-behind-our-momentum/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/from-what-if-to-even-if-the-mindset-behind-our-momentum/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: scraping url -> https://www.occamsadvisory.com/employer-of-record
# The Webpage Employer of Record | Occams Advisory got fully loaded.
# content length: 13316 chars
#
# content snippet: Employer of Record | Occams Advisory
# Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payment
#
#
# --------------------------------------------------
#
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: scraping url -> https://www.occamsadvisory.com/structuring-incorporation-accounting-advisory
# The Webpage Structuring, Incorporation & Accounting Advisory | Occam's Advisory got fully loaded.
# content length: 46253 chars
#
# content snippet: Structuring, Incorporation & Accounting Advisory | Occam's Advisory
# Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payment
#
#
# --------------------------------------------------
#
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/digital-presence-social-media
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/from-what-if-to-even-if-the-mindset-behind-our-momentum/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/from-what-if-to-even-if-the-mindset-behind-our-momentum/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: scraping url -> https://www.occamsadvisory.com/process-efficiency-compliance-tax-planning-filing
# The Webpage Process Efficiency, Compliance & Tax Planning | Occam's Advisory got fully loaded.
# content length: 47252 chars
#
# content snippet: Process Efficiency, Compliance & Tax Planning | Occam's Advisory
# Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payment
#
#
# --------------------------------------------------
#
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/from-what-if-to-even-if-the-mindset-behind-our-momentum/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/from-what-if-to-even-if-the-mindset-behind-our-momentum/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: scraping url -> https://www.occamsadvisory.com/information-technology-services
# The Webpage Information Technology Services | Enhance Your Business with Occam's Advisory got fully loaded.
# content length: 45063 chars
#
# content snippet: Information Technology Services | Enhance Your Business with Occam's Advisory
# Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payment
#
#
# --------------------------------------------------
#
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/from-what-if-to-even-if-the-mindset-behind-our-momentum/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/from-what-if-to-even-if-the-mindset-behind-our-momentum/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: scraping url -> https://www.occamsadvisory.com/merchant-accounts-across-the-globe
# The Webpage Global Merchant Account Solutions | Expand with Occam's Advisory got fully loaded.
# content length: 44671 chars
#
# content snippet: Global Merchant Account Solutions | Expand with Occam's Advisory
# Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payment
#
#
# --------------------------------------------------
#
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/from-what-if-to-even-if-the-mindset-behind-our-momentum/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/from-what-if-to-even-if-the-mindset-behind-our-momentum/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: scraping url -> https://www.occamsadvisory.com/tailored-payment-solutions-verification-services
# The Webpage Tailored Payment Solutions & Verification Services | Occam's Advisory got fully loaded.
# content length: 44733 chars
#
# content snippet: Tailored Payment Solutions & Verification Services | Occam's Advisory
# Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payment
#
#
# --------------------------------------------------
#
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/from-what-if-to-even-if-the-mindset-behind-our-momentum/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/from-what-if-to-even-if-the-mindset-behind-our-momentum/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: scraping url -> https://www.occamsadvisory.com/customized-payment-risk-management-analytics
# The Webpage Customized Payment Risk Management & Analytics | Occam's Advisory got fully loaded.
# content length: 45176 chars
#
# content snippet: Customized Payment Risk Management & Analytics | Occam's Advisory
# Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payment
#
#
# --------------------------------------------------
#
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/from-what-if-to-even-if-the-mindset-behind-our-momentum/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/from-what-if-to-even-if-the-mindset-behind-our-momentum/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: scraping url -> https://www.occamsadvisory.com/proprietary-fintech-platform
# The Webpage Proprietary FinTech Platform | Revolutionize Your Business with Occam's Advisory got fully loaded.
# content length: 44881 chars
#
# content snippet: Proprietary FinTech Platform | Revolutionize Your Business with Occam's Advisory
# Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payme
#
# --------------------------------------------------
#
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/from-what-if-to-even-if-the-mindset-behind-our-momentum/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/from-what-if-to-even-if-the-mindset-behind-our-momentum/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: scraping url -> https://www.occamsadvisory.com/capital-raising-to-promote-growth
# The Webpage Capital Raising for Business Growth | Occam's Advisory got fully loaded.
# content length: 44965 chars
#
# content snippet: Capital Raising for Business Growth | Occam's Advisory
# Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payment
#
#
# --------------------------------------------------
#
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/from-what-if-to-even-if-the-mindset-behind-our-momentum/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/from-what-if-to-even-if-the-mindset-behind-our-momentum/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: scraping url -> https://www.occamsadvisory.com/financial-advisory-and-transaction-integration
# The Webpage Financial Advisory & Transaction Integration | Occam's Advisory got fully loaded.
# content length: 45179 chars
#
# content snippet: Financial Advisory & Transaction Integration | Occam's Advisory
# Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payment
#
#
# --------------------------------------------------
#
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/from-what-if-to-even-if-the-mindset-behind-our-momentum/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/from-what-if-to-even-if-the-mindset-behind-our-momentum/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: scraping url -> https://www.occamsadvisory.com/sell-side-ma
# The Webpage Sell-Side M&A Services | Maximize Value with Occam's Advisory got fully loaded.
# content length: 45396 chars
#
# content snippet: Sell-Side M&A Services | Maximize Value with Occam's Advisory
# Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payment
#
#
# --------------------------------------------------
#
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/from-what-if-to-even-if-the-mindset-behind-our-momentum/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/occams-advisory-honored-as-one-of-the-best-workplaces-of-2025-by-inc/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/trumps-one-big-beautiful-bill-act-what-it-means-for-small-business-owners
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/from-what-if-to-even-if-the-mindset-behind-our-momentum/
# ...
# DEBUG: scraping url -> https://www.occamsadvisory.com/insights?sort=popularity&page=3
# The Webpage Occams Advisory | Global Financing Advisory & Professional Services got fully loaded.
# content length: 10412 chars
#
# content snippet: Occams Advisory | Global Financing Advisory & Professional Services
# Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payment
#
#
# --------------------------------------------------
#
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: scraping url -> https://www.occamsadvisory.com/insights/8-tax-credits-to-save-you-tens-of-thousands-of-dolllars
# The Webpage  got fully loaded.
# content length: 8568 chars
#
# content snippet: Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payment
#                                                                     Solutions
#
#
# --------------------------------------------------
#
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: scraping url -> https://www.occamsadvisory.com/insights?topic=insights-101&page=2
# The Webpage Occams Advisory | Global Financing Advisory & Professional Services got fully loaded.
# content length: 10781 chars
#
# content snippet: Occams Advisory | Global Financing Advisory & Professional Services
# Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payment
#
#
# --------------------------------------------------
#
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: adding to the queue -> https://www.occamsadvisory.com/insights?topic=insights-101&page=1
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: scraping url -> https://www.occamsadvisory.com/insights?topic=insights-101&page=3
# The Webpage Occams Advisory | Global Financing Advisory & Professional Services got fully loaded.
# content length: 10102 chars
#
# content snippet: Occams Advisory | Global Financing Advisory & Professional Services
# Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payment
#
#
# --------------------------------------------------
#
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: scraping url -> https://www.occamsadvisory.com/insights/employee-retention-credit-fact-or-fiction
# The Webpage  got fully loaded.
# content length: 8568 chars
#
# content snippet: Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payment
#                                                                     Solutions
#
#
# --------------------------------------------------
#
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: scraping url -> https://www.occamsadvisory.com/insights/erc-success-stories-in-florida
# The Webpage  got fully loaded.
# content length: 8568 chars
#
# content snippet: Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payment
#                                                                     Solutions
#
#
# --------------------------------------------------
#
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: scraping url -> https://www.occamsadvisory.com/insights/evolution-of-accounting-technology
# The Webpage  got fully loaded.
# content length: 8568 chars
#
# content snippet: Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payment
#                                                                     Solutions
#
#
# --------------------------------------------------
#
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: scraping url -> https://www.occamsadvisory.com/insights?page=1
# The Webpage Occams Advisory | Global Financing Advisory & Professional Services got fully loaded.
# content length: 10854 chars
#
# content snippet: Occams Advisory | Global Financing Advisory & Professional Services
# Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payment
#
#
# --------------------------------------------------
#
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: scraping url -> https://www.occamsadvisory.com/insights?sort=newest&page=1
# The Webpage Occams Advisory | Global Financing Advisory & Professional Services got fully loaded.
# content length: 10770 chars
#
# content snippet: Occams Advisory | Global Financing Advisory & Professional Services
# Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payment
#
#
# --------------------------------------------------
#
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: scraping url -> https://www.occamsadvisory.com/insights?sort=popularity&page=1
# The Webpage Occams Advisory | Global Financing Advisory & Professional Services got fully loaded.
# content length: 10875 chars
#
# content snippet: Occams Advisory | Global Financing Advisory & Professional Services
# Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payment
#
#
# --------------------------------------------------
#
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: scraping url -> https://www.occamsadvisory.com/insights?topic=insights-101&page=1
# The Webpage Occams Advisory | Global Financing Advisory & Professional Services got fully loaded.
# content length: 10813 chars
#
# content snippet: Occams Advisory | Global Financing Advisory & Professional Services
# Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payment
#
#
# --------------------------------------------------
#
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/media-mentions
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/press-release/
# DEBUG: skipping blog page -> https://www.occamsadvisory.com/blog/
# DEBUG: skipping blog page -> https://occamsadvisory.com/blog/press-release/
# DEBUG: skipping podcast -> https://www.occamsadvisory.com/podcasts
# Scarping completed......
# No of pages scraped: 156

# %%
print(f'TOTAL URLs scraped: {len(scraped_data)}')
# Out:
# TOTAL URLs scraped: 156

# %%
for i in scraped_data[:3]:
    print(f"URL: {i['url']}\n Snippet: {i['content'][:10000]}\n {'-'*50}")
# Out:
# URL: https://www.occamsadvisory.com/
#  Snippet: Occams Advisory | Global Financing Advisory & Professional Services
# Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payment
#                                                                     Solutions
# CMIB
# Capital Market & Investment Banking
# TC
# Tax Advisory and Tax Credits
# Employer of
#                                                                     Record (EOR)
# We handle payroll, contracts, taxes, and benefits, so
#                                                                     you can focus on growth.
# Structuring,
#                                                                     Incorporation & Accounting Advisory
# Expert guidance for business formation, legal
#                                                                     structuring, and financial setup.
# Process
#                                                                     Efficiency, Compliance, Tax Planning & Filing
# Streamlining operations, ensuring regulatory
#                                                                     adherence,
#                                                                     and optimizing tax strategies.
# Information
#                                                                     Technology Services
# Delivering innovative tech solutions to enhance
#                                                                     operations and drive business growth.
# Digital
# Crafting strong brand identity, engaging customers
#                                                                     and
#                                                                     fostering active community engagement.
# Learn more about BSGI services
# Discover comprehensive
#                                                                 solutions designed to accelerate
#                                                                 your business success.
# Need different services?
# Our team is always at your disposal.
# Talk
#                                                                 to support
# Merchant
#                                                                     Accounts Across the Globe
# Facilitating global payment acceptance for businesses
#                                                                     through diverse merchant accounts.
# Tailored
#                                                                     Payment
#                                                                     Solutions & Verification Services
# Customized payment processing and robust identity
#                                                                     verification for transactions.
# Customized
#                                                                     Payment
#                                                                     Risk Management & Analytics
# Mitigating transaction risks and analyzing data for
#                                                                     secure payment operations.
# Proprietary
#                                                                     Fintech Platform
# An innovative, in-house financial technology platform
#                                                                     driving modern payment solutions.
# Learn more about FTPS services
# Discover comprehensive
#                                                                 solutions designed to accelerate
#                                                                 your business success.
# Need different services?
# Our team is always at your disposal.
# Talk
#                                                                 to support
# Capital
#                                                                     Raising to Promote Growth
# Securing vital funds to fuel business expansion and
#                                                                     strategic development.
# Financial
#                                                                     Advisory
#                                                                     and Transaction Integration
# Expert guidance for financial decisions and seamless
#                                                                     deal
#                                                                     execution.
# Sell-Side M&A
# dvising companies on strategic sales, ensuring
#                                                                     optimal
#                                                                     value realization.
# Buy-Side M&A
# ssisting in identifying, acquiring, and integrating
#                                                                     target companies effectively.
# Decision
#                                                                     Science
#                                                                     and Risk Assurance
# Leveraging data for informed decisions and robust
#                                                                     risk
#                                                                     mitigation.
# Learn more about CMIB services
# Discover comprehensive
#                                                                 solutions designed to accelerate
#                                                                 your business success.
# Need different services?
# Our team is always at your disposal.
# Talk
#                                                                 to support
# Employee
#                                                                     Retention Credit (ERC)
# COVID-19 relief for businesses retaining employees
#                                                                     despite pandemic impacts.
# Research &
#                                                                     Development Tax Credit for 2024
# Incentivizes businesses for innovation through
#                                                                     qualified research activities in 2024.
# Learn more about TC services
# Discover comprehensive
#                                                                 solutions designed to accelerate
#                                                                 your business success.
# Need different services?
# Our team is always at your disposal.
# Talk
#                                                                 to support
# Digital
# Team
# Resources
# Resources
# BLOGS
# Recognitions
# PODCAST & WEBINAR
# Media
#                                                             Mentions
# EVENTS
# MICRO INSIGHTS
# Video Testimonials
# Press
#                                                             Release
# Contact
# Login
# Career
# Blog
# Awards
# About
# Services
# Digital
# Team
# Resources
# Contact
# Login
# Back
# OVERVIEW
# BSGI
# Business Services &
# Growth Incubation
# FTPS
# Financial Technology &
# Payment Solutions
# CMIB
# Capital Markets &
# Investment Banking
# TC
# Tax Advisory and Tax Credits
# Back
# Blogs
# Podcast & Webinar
# Events
# Micro Insights
# Recognitions
# Media Mentions
# Testimonials
# Press Releases
# Your browser does not support the video tag.
# Occams Digital
# One Subscription. On-Demand. Unlimited Leverage
# From strategy to execution, Occams Digital delivers agile,
#                                         end-to-end digital marketing solutions for businesses ready to scale.
# Know More
# Business
#                                         Incubation
# Join thousands of SMB's that have put their trust in Occams
# Our world class advisory services are here to help you
#                                         conveniently set up and
#                                         manage your business.
# Grow your Company with
#                                             us
# Maximize Your Innovation with R&D Tax Credits
# Unlock Tax Savings Across All Industries - From Software to
#                                         Retail
# Benefit from claiming R&D tax credits to offset future income
#                                         tax, with
#                                         carryforwards up to 20 years.
# Claim Your R&D
#                                             Credits
#                                             Today
# Ai Powered
# Future - Predicted. Perfected. Presented
# Welcome to the future of your business. At Occams, we combine
#                                         our insatiable
#                                         curiosity with our unwavering inspiration to predict and produce your dream
#                                         outcome
# Talk to Us!
# Occams Digital
# One Subscription. On-Demand. Unlimited Leverage
# From strategy to execution, Occams Digital delivers agile,
#                                         end-to-end digital marketing solutions for businesses ready to scale.
# Know More
# Business
#                                         Incubation
# Join thousands of SMB's that have put their trust in Occams
# Our world class advisory services are here to help you
#                                         conveniently set up and
#                                         manage your business.
# Grow your Company with
#                                             us
# 1
# 2
# 3
# 4
# 1.68MM
# Bitcoin
#                                 Treasury (USD Value)
# $114,848.00
# BTC/USD
# $102,995.00
# Avg.
#                             cost/BTC
# 14.650 BTC
# BTC
#                             Balance
# Our Bitcoin
#                             Treasury
# Our bitcoins are held in a fault tolerant multi-institutional custody.
# 1.68MM
# Bitcoin
#                                 Treasury (USD Value)
# $114,848.00
# BTC/USD
# $102,995.00
# Avg.
#                             cost/BTC
# 14.650 BTC
# BTC
#                             Balance
# Our Bitcoin
#                             Treasury
# Our bitcoins are held in a fault tolerant multi-institutional custody.
# Your browser does not support the video tag.
# Occams Digital
# One Subscription. On-Demand. Unlimited Leverage
# From strategy to execution, Occams Digital delivers agile,
#                                         end-to-end digital marketing solutions for businesses ready to scale.
# Know More
# Business
#                                         Incubation
# Join thousands of SMB's that have put
#  --------------------------------------------------
# URL: https://www.occamsadvisory.com/career
#  Snippet: Career | Occams Advisory
# Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payment
#                                                                     Solutions
# CMIB
# Capital Market & Investment Banking
# TC
# Tax Advisory and Tax Credits
# Employer of
#                                                                     Record (EOR)
# We handle payroll, contracts, taxes, and benefits, so
#                                                                     you can focus on growth.
# Structuring,
#                                                                     Incorporation & Accounting Advisory
# Expert guidance for business formation, legal
#                                                                     structuring, and financial setup.
# Process
#                                                                     Efficiency, Compliance, Tax Planning & Filing
# Streamlining operations, ensuring regulatory
#                                                                     adherence,
#                                                                     and optimizing tax strategies.
# Information
#                                                                     Technology Services
# Delivering innovative tech solutions to enhance
#                                                                     operations and drive business growth.
# Digital
# Crafting strong brand identity, engaging customers
#                                                                     and
#                                                                     fostering active community engagement.
# Learn more about BSGI services
# Discover comprehensive
#                                                                 solutions designed to accelerate
#                                                                 your business success.
# Need different services?
# Our team is always at your disposal.
# Talk
#                                                                 to support
# Merchant
#                                                                     Accounts Across the Globe
# Facilitating global payment acceptance for businesses
#                                                                     through diverse merchant accounts.
# Tailored
#                                                                     Payment
#                                                                     Solutions & Verification Services
# Customized payment processing and robust identity
#                                                                     verification for transactions.
# Customized
#                                                                     Payment
#                                                                     Risk Management & Analytics
# Mitigating transaction risks and analyzing data for
#                                                                     secure payment operations.
# Proprietary
#                                                                     Fintech Platform
# An innovative, in-house financial technology platform
#                                                                     driving modern payment solutions.
# Learn more about FTPS services
# Discover comprehensive
#                                                                 solutions designed to accelerate
#                                                                 your business success.
# Need different services?
# Our team is always at your disposal.
# Talk
#                                                                 to support
# Capital
#                                                                     Raising to Promote Growth
# Securing vital funds to fuel business expansion and
#                                                                     strategic development.
# Financial
#                                                                     Advisory
#                                                                     and Transaction Integration
# Expert guidance for financial decisions and seamless
#                                                                     deal
#                                                                     execution.
# Sell-Side M&A
# dvising companies on strategic sales, ensuring
#                                                                     optimal
#                                                                     value realization.
# Buy-Side M&A
# ssisting in identifying, acquiring, and integrating
#                                                                     target companies effectively.
# Decision
#                                                                     Science
#                                                                     and Risk Assurance
# Leveraging data for informed decisions and robust
#                                                                     risk
#                                                                     mitigation.
# Learn more about CMIB services
# Discover comprehensive
#                                                                 solutions designed to accelerate
#                                                                 your business success.
# Need different services?
# Our team is always at your disposal.
# Talk
#                                                                 to support
# Employee
#                                                                     Retention Credit (ERC)
# COVID-19 relief for businesses retaining employees
#                                                                     despite pandemic impacts.
# Research &
#                                                                     Development Tax Credit for 2024
# Incentivizes businesses for innovation through
#                                                                     qualified research activities in 2024.
# Learn more about TC services
# Discover comprehensive
#                                                                 solutions designed to accelerate
#                                                                 your business success.
# Need different services?
# Our team is always at your disposal.
# Talk
#                                                                 to support
# Digital
# Team
# Resources
# Resources
# BLOGS
# Recognitions
# PODCAST & WEBINAR
# Media
#                                                             Mentions
# EVENTS
# MICRO INSIGHTS
# Video Testimonials
# Press
#                                                             Release
# Contact
# Login
# Career
# Blog
# Awards
# About
# Services
# Digital
# Team
# Resources
# Contact
# Login
# Back
# OVERVIEW
# BSGI
# Business Services &
# Growth Incubation
# FTPS
# Financial Technology &
# Payment Solutions
# CMIB
# Capital Markets &
# Investment Banking
# TC
# Tax Advisory and Tax Credits
# Back
# Blogs
# Podcast & Webinar
# Events
# Micro Insights
# Recognitions
# Media Mentions
# Testimonials
# Press Releases
# Recognizing Potential. Driving Results. Creating Impact.
# At Occams, our people are at the heart of everything we do. We
#                             believe in helping each person
#                             grow in a way that supports both their career goals and our company’s vision. That’s how we
#                             attract great talent, keep them engaged, and create lasting value for everyone.
# Find a Job
# The HCMI North Star
# How we we work
# Our people priorities
# The Occams edge
# Working at Occams
# Our Guiding Belief:
# The HCMI North Star
# We work side by side with our people to help them reach their full
#                             potential, making sure their
#                             career paths are clearly connected to where Occams is heading. This belief is behind everything
#                             we do, from how we lead and collaborate to how we innovate and move forward.
# Find a Job
# Mission & Values
# How We Work
# Our culture is shaped by a few key principles:
# 3/6
# 3. Supportive Leadership
# Our leaders focus on helping others grow, not just evaluating performance.
# 4. Smart Use of Technology
# 5. Clear and Fast Execution
# Our
#                             People Priorities
# Here’s what we focus on to make Occams a place where people thrive
# Purpose
# Everyone should know why their work matters — to themselves, their
#                                     team, and our business.
# Clear Focus
# We make sure people understand what’s most important and how they can
#                                 contribute.
# Lean Structure
# No layers for the sake of it. We keep things flat, efficient, &
#                                     agile.
# Quick, Smart Decisions
# We act with a bias for action. We base decisions on data and facts,
#                                     not just opinions.
# Always Learning
# Continuous learning is our default mode. We learn by doing, sharing,
#                                     and improving continuously.
# Talent Is Everything
# We invest in people, especially in the roles that matter most to our
#                                 success.
# Culture That Matters
# We move quickly, focus on value creation, keep our people  at the
#                                     center, and treat each other with respect and appreciation.
# Connected Thinking
# We build partnerships across teams, functions, and ecosystems to help
#                                 everyone succeed.
# Technology with Purpose
# We treat data as a core business asset — it guides our decisions,
#                                     our growth, and our innovation.
# Purpose
# Everyone should know why their work matters — to themselves, their
#                                     team, and our business.
# Clear Focus
# We make sure people understand what’s most important and how they can
#                                 contribute.
# Always Learning
# Continuous learning is our default mode. We learn by doing, sharing,
#                                     and improving continuously.
# Talent Is Everything
# We invest in people, especially in the roles that matter most to our
#                                 success.
# Lean Structure
# No layers for the s
#  --------------------------------------------------
# URL: https://www.occamsadvisory.com/awards
#  Snippet: Occams Advisory: Award-Winning Innovations and Recognitions
# Career
# Blog
# Awards
# About
# Services
# Services
# BSGI
# Business Services & Growth Incubation
# FTPS
# Financial Technology & Payment
#                                                                     Solutions
# CMIB
# Capital Market & Investment Banking
# TC
# Tax Advisory and Tax Credits
# Employer of
#                                                                     Record (EOR)
# We handle payroll, contracts, taxes, and benefits, so
#                                                                     you can focus on growth.
# Structuring,
#                                                                     Incorporation & Accounting Advisory
# Expert guidance for business formation, legal
#                                                                     structuring, and financial setup.
# Process
#                                                                     Efficiency, Compliance, Tax Planning & Filing
# Streamlining operations, ensuring regulatory
#                                                                     adherence,
#                                                                     and optimizing tax strategies.
# Information
#                                                                     Technology Services
# Delivering innovative tech solutions to enhance
#                                                                     operations and drive business growth.
# Digital
# Crafting strong brand identity, engaging customers
#                                                                     and
#                                                                     fostering active community engagement.
# Learn more about BSGI services
# Discover comprehensive
#                                                                 solutions designed to accelerate
#                                                                 your business success.
# Need different services?
# Our team is always at your disposal.
# Talk
#                                                                 to support
# Merchant
#                                                                     Accounts Across the Globe
# Facilitating global payment acceptance for businesses
#                                                                     through diverse merchant accounts.
# Tailored
#                                                                     Payment
#                                                                     Solutions & Verification Services
# Customized payment processing and robust identity
#                                                                     verification for transactions.
# Customized
#                                                                     Payment
#                                                                     Risk Management & Analytics
# Mitigating transaction risks and analyzing data for
#                                                                     secure payment operations.
# Proprietary
#                                                                     Fintech Platform
# An innovative, in-house financial technology platform
#                                                                     driving modern payment solutions.
# Learn more about FTPS services
# Discover comprehensive
#                                                                 solutions designed to accelerate
#                                                                 your business success.
# Need different services?
# Our team is always at your disposal.
# Talk
#                                                                 to support
# Capital
#                                                                     Raising to Promote Growth
# Securing vital funds to fuel business expansion and
#                                                                     strategic development.
# Financial
#                                                                     Advisory
#                                                                     and Transaction Integration
# Expert guidance for financial decisions and seamless
#                                                                     deal
#                                                                     execution.
# Sell-Side M&A
# dvising companies on strategic sales, ensuring
#                                                                     optimal
#                                                                     value realization.
# Buy-Side M&A
# ssisting in identifying, acquiring, and integrating
#                                                                     target companies effectively.
# Decision
#                                                                     Science
#                                                                     and Risk Assurance
# Leveraging data for informed decisions and robust
#                                                                     risk
#                                                                     mitigation.
# Learn more about CMIB services
# Discover comprehensive
#                                                                 solutions designed to accelerate
#                                                                 your business success.
# Need different services?
# Our team is always at your disposal.
# Talk
#                                                                 to support
# Employee
#                                                                     Retention Credit (ERC)
# COVID-19 relief for businesses retaining employees
#                                                                     despite pandemic impacts.
# Research &
#                                                                     Development Tax Credit for 2024
# Incentivizes businesses for innovation through
#                                                                     qualified research activities in 2024.
# Learn more about TC services
# Discover comprehensive
#                                                                 solutions designed to accelerate
#                                                                 your business success.
# Need different services?
# Our team is always at your disposal.
# Talk
#                                                                 to support
# Digital
# Team
# Resources
# Resources
# BLOGS
# Recognitions
# PODCAST & WEBINAR
# Media
#                                                             Mentions
# EVENTS
# MICRO INSIGHTS
# Video Testimonials
# Press
#                                                             Release
# Contact
# Login
# Career
# Blog
# Awards
# About
# Services
# Digital
# Team
# Resources
# Contact
# Login
# Back
# OVERVIEW
# BSGI
# Business Services &
# Growth Incubation
# FTPS
# Financial Technology &
# Payment Solutions
# CMIB
# Capital Markets &
# Investment Banking
# TC
# Tax Advisory and Tax Credits
# Back
# Blogs
# Podcast & Webinar
# Events
# Micro Insights
# Recognitions
# Media Mentions
# Testimonials
# Press Releases
# Awards & Recognitions
# Awards & Recognitions
# All
# Business And
#                         Innovation
# Diversity,
#                         Equality and Inclusion
# Employer of
#                         Choice
# INC 5000
# Fastest Growing US Companies – 2016 to 2021, 2023, 2024 and 2025
# Occams Advisory, a 9-time Inc. 5000 honoree, helps businesses grow smarter
#                             with strategic, financial, tech, and Bitcoin-native solutions that drive innovation and impact.
# INC Best Workplaces 2025
# June 2025
# Occams Advisory is proud to be named one of INC. Best Workplaces 2025. This
#                             recognition reflects our culture of clarity, trust, and purpose, driven by shared values and a
#                             commitment to empowering people and delivering meaningful outcomes. It’s more than an honor;
#                             it’s the Occams Way.
# Financial Times’ The Americas’ Fastest-Growing Companies - 2020 to
#                             2023, 2025
# Rank 159
# Occams Advisory is thrilled to be recognized in the Financial Times' 2025
#                             list of the Americas' Fastest-Growing Companies. This achievement underscores our relentless
#                             pursuit of excellence and innovation, driving sustained growth and industry leadership.
# INC Regionals Southeast - April 2025
# Rank 39
# The Inc. Southeast Regionals recognizes the region’s fastest-growing
#                             private companies, spotlighting innovation, leadership, and transformative impact. This
#                             prestigious list celebrates those driving economic progress and setting bold new standards for
#                             success.
# Gold Stevie Award - March 2025
# Achievement in Customer Service Excellence - Business Service
# Occams Advisory is proud to receive the 2025 Stevie Award for Customer
#                             Service Success in the Business Service Industries category. This prestigious recognition
#                             reflects our commitment to exceptional service and client satisfaction.
# SB100 Award - Dec, 2024
# Leading the Way in Business Innovation!
# Occams Advisory is thrilled to announce our recognition as one of the Top
#                             100 Small to Mid-Sized Businesses in the prestigious SB100 2024 Awards. This accolade
#                             underscores our unwavering commitment to excellence, innovation, and sustainable business
#                             practices.
# BASA award in Business Consulting - Nov, 2024
# Best Small Business of the Year
# Occams Advisory is proud to be named Best Small Business of the Year in
#                             Business Consulting at the BASA Awards® 2024, recognizing our dedication to empowering small and
#                             medium businesses with Fortune 500 expertise and innovative solutions.
# Global Recognition Award - July, 2024
# Excellence in Business Innovation & Advisory
# Occams Advisory is honored to receive the 2024 Global Recognition Award for
#                             excellence in delivering innovative solutions and ad
#  --------------------------------------------------

# %%
with open('occams_scraped_data.json', 'w') as f:
    json.dump(scraped_data, f, indent=4)
print("saved as json ....")
# Out:
# saved as json ....
